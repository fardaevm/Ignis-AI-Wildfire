# %%
import pandas as pd

# Packages used for filtering based on California boundary
import shapefile
from shapely.geometry import shape, Point
from shapely.ops import unary_union

# %%
climate_data = pd.read_csv('./datasets/CIMIS/processed/daily_CIMIS.csv')
fire_data = pd.read_csv('./datasets/DL_FIRE_SV-C2/fire_archive_SV-C2.csv')
station_data = pd.read_csv('cimis_station_info.csv')

# %%
climate_data.shape
# Out:
# (216645, 33)

# %%
fire_data.shape
# Out:
# (354319, 15)

# %%
climate_data.head()
# Out:
#    Stn Id           Stn Name               CIMIS Region      Date  Jul  \
# 0     181  Westmorland North  Imperial/Coachella Valley  1/1/2021    1
# 1     181  Westmorland North  Imperial/Coachella Valley  1/2/2021    2
# 2     181  Westmorland North  Imperial/Coachella Valley  1/3/2021    3
# 3     181  Westmorland North  Imperial/Coachella Valley  1/4/2021    4
# 4     181  Westmorland North  Imperial/Coachella Valley  1/5/2021    5
#
#    ETo (mm) qc  Precip (mm) qc.1  Sol Rad (W/sq.m)  ... Avg Rel Hum (%)  qc.9  \
# 0      1.96             0.0                  159.0  ...            51.0
# 1      1.63             0.0                  152.0  ...            65.0
# 2      1.57  R          0.0                  149.0  ...            67.0
# 3      1.69  R          0.0                  154.0  ...            68.0
# 4      1.74             0.0                  162.0  ...            73.0
#
#   Dew Point (C)  qc.10 Avg Wind Speed (m/s)  qc.11 Wind Run (km)  qc.12  \
# 0           2.5                         1.2                 99.9
# 1           2.9                         0.5                 40.6
# 2           3.9                         0.5                 40.8
# 3           4.6                         0.5                 39.0
# 4           5.5                         0.6                 48.5
#
#   Avg Soil Temp (C)  qc.13
# 0              11.0
# 1              11.0
# 2              10.9
# 3              10.8
# 4              10.9
#
# [5 rows x 33 columns]

# %%
fire_data.head()
# Out:
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0  42.14804 -121.21143      301.73  0.43   0.38  2021-01-01       948
# 1  42.14388 -121.20705      296.58  0.43   0.38  2021-01-01       948
# 2  42.14107 -121.21310      311.14  0.43   0.38  2021-01-01       948
# 3  42.13758 -121.21394      332.16  0.43   0.38  2021-01-01       948
# 4  42.13826 -121.21915      306.48  0.43   0.38  2021-01-01       948
#
#   satellite instrument confidence  version  bright_t31   frp daynight  type
# 0         N      VIIRS          n        2      266.88  0.80        N     0
# 1         N      VIIRS          n        2      266.42  1.23        N     0
# 2         N      VIIRS          n        2      266.68  1.23        N     0
# 3         N      VIIRS          n        2      268.83  2.64        N     0
# 4         N      VIIRS          n        2      266.10  1.41        N     0

# %%
station_data.head()
# Out:
#    StationNbr                  Name         City               RegionalOffice  \
# 0           1    Fresno/F.S.U. USDA       Fresno  South Central Region Office
# 1           2            FivePoints  Five Points  South Central Region Office
# 2           3  Beach /Santa Cruz CO  Watsonville  South Central Region Office
# 3           4   Webb /Santa Cruz CO  Watsonville  South Central Region Office
# 4           5               Shafter      Shafter  South Central Region Office
#
#        County ConnectDate DisconnectDate  IsActive  IsEtoStation  Elevation  \
# 0      Fresno    6/7/1982      9/25/1988     False          True        340
# 1      Fresno    6/7/1982     12/31/2050      True          True        285
# 2  Santa Cruz   5/30/1982      8/25/1986     False          True         10
# 3  Santa Cruz   5/30/1982      4/29/1988     False          True        230
# 4        Kern    6/1/1982     12/31/2050      True         False        360
#
#   GroundCover            HmsLatitude               HmsLongitude  \
# 0       Grass  36º48'52N / 36.814444  -119º43'54W / -119.731670
# 1       Grass  36º20'10N / 36.336222   -120º6'46W / -120.112910
# 2       Grass  36º52'50N / 36.880556  -121º47'36W / -121.793330
# 3       Grass    36º58'21N / 36.9725  -121º43'34W / -121.726110
# 4       Grass  35º31'57N / 35.532556  -119º16'54W / -119.281790
#
#                                             ZipCodes  SitingDesc
# 0  ['93766', '93762', '93761', '93760', '93759', ...         NaN
# 1                                          ['93624']         NaN
# 2      ['95077', '95076', '95075', '95019', '95018']         NaN
# 3      ['95077', '95076', '95075', '95019', '95018']         NaN
# 4                        ['93263', '93280', '93388']         NaN

# %%
# Update the station_data and change the latitude and longitude format to float
def extract_decimal(coord):
    try:
        return float(coord.split('/')[1].strip())
    except:
        return None
    
station_data['Latitude'] = station_data['HmsLatitude'].apply(extract_decimal)
station_data['Longitude'] = station_data['HmsLongitude'].apply(extract_decimal)

station_data = station_data.drop(columns=['HmsLatitude', 'HmsLongitude'])

# %%
station_data.head()
# Out:
#    StationNbr                  Name         City               RegionalOffice  \
# 0           1    Fresno/F.S.U. USDA       Fresno  South Central Region Office
# 1           2            FivePoints  Five Points  South Central Region Office
# 2           3  Beach /Santa Cruz CO  Watsonville  South Central Region Office
# 3           4   Webb /Santa Cruz CO  Watsonville  South Central Region Office
# 4           5               Shafter      Shafter  South Central Region Office
#
#        County ConnectDate DisconnectDate  IsActive  IsEtoStation  Elevation  \
# 0      Fresno    6/7/1982      9/25/1988     False          True        340
# 1      Fresno    6/7/1982     12/31/2050      True          True        285
# 2  Santa Cruz   5/30/1982      8/25/1986     False          True         10
# 3  Santa Cruz   5/30/1982      4/29/1988     False          True        230
# 4        Kern    6/1/1982     12/31/2050      True         False        360
#
#   GroundCover                                           ZipCodes  SitingDesc  \
# 0       Grass  ['93766', '93762', '93761', '93760', '93759', ...         NaN
# 1       Grass                                          ['93624']         NaN
# 2       Grass      ['95077', '95076', '95075', '95019', '95018']         NaN
# 3       Grass      ['95077', '95076', '95075', '95019', '95018']         NaN
# 4       Grass                        ['93263', '93280', '93388']         NaN
#
#     Latitude  Longitude
# 0  36.814444 -119.73167
# 1  36.336222 -120.11291
# 2  36.880556 -121.79333
# 3  36.972500 -121.72611
# 4  35.532556 -119.28179

# %%
# Merge station's latitude and longitude to CIMIS dataset using station number
# Drop the StationNbr column after merging - no need for redundancy 
climate_data = climate_data.merge(
    station_data[['StationNbr', 'Latitude', 'Longitude']], 
    left_on="Stn Id", 
    right_on="StationNbr", 
    how="left").drop(columns=['StationNbr'])

climate_data.head()
# Out:
#    Stn Id           Stn Name               CIMIS Region      Date  Jul  \
# 0     181  Westmorland North  Imperial/Coachella Valley  1/1/2021    1
# 1     181  Westmorland North  Imperial/Coachella Valley  1/2/2021    2
# 2     181  Westmorland North  Imperial/Coachella Valley  1/3/2021    3
# 3     181  Westmorland North  Imperial/Coachella Valley  1/4/2021    4
# 4     181  Westmorland North  Imperial/Coachella Valley  1/5/2021    5
#
#    ETo (mm) qc  Precip (mm) qc.1  Sol Rad (W/sq.m)  ... Dew Point (C)  qc.10  \
# 0      1.96             0.0                  159.0  ...           2.5
# 1      1.63             0.0                  152.0  ...           2.9
# 2      1.57  R          0.0                  149.0  ...           3.9
# 3      1.69  R          0.0                  154.0  ...           4.6
# 4      1.74             0.0                  162.0  ...           5.5
#
#   Avg Wind Speed (m/s)  qc.11 Wind Run (km)  qc.12 Avg Soil Temp (C)  qc.13  \
# 0                  1.2                 99.9                     11.0
# 1                  0.5                 40.6                     11.0
# 2                  0.5                 40.8                     10.9
# 3                  0.5                 39.0                     10.8
# 4                  0.6                 48.5                     10.9
#
#     Latitude  Longitude
# 0  33.078611 -115.66056
# 1  33.078611 -115.66056
# 2  33.078611 -115.66056
# 3  33.078611 -115.66056
# 4  33.078611 -115.66056
#
# [5 rows x 35 columns]

# %%
fire_data.head()
# Out:
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0  42.14804 -121.21143      301.73  0.43   0.38  2021-01-01       948
# 1  42.14388 -121.20705      296.58  0.43   0.38  2021-01-01       948
# 2  42.14107 -121.21310      311.14  0.43   0.38  2021-01-01       948
# 3  42.13758 -121.21394      332.16  0.43   0.38  2021-01-01       948
# 4  42.13826 -121.21915      306.48  0.43   0.38  2021-01-01       948
#
#   satellite instrument confidence  version  bright_t31   frp daynight  type
# 0         N      VIIRS          n        2      266.88  0.80        N     0
# 1         N      VIIRS          n        2      266.42  1.23        N     0
# 2         N      VIIRS          n        2      266.68  1.23        N     0
# 3         N      VIIRS          n        2      268.83  2.64        N     0
# 4         N      VIIRS          n        2      266.10  1.41        N     0

# %%
print('Shape of unfiltered fire data:', fire_data.shape)

# Load CA shapefile (e.g. county subdivisions)
sf = shapefile.Reader("./ca/tl_2019_06_cousub.shp")
shapes = [shape(record.shape.__geo_interface__) for record in sf.shapeRecords()]

# Combine all shapes into one multipolygon
california_shape = unary_union(shapes)

# Convert fire points to shapely Point geometries
fire_data['geometry'] = fire_data.apply(lambda row: Point(row['longitude'], row['latitude']), axis=1)

# Filter: keep only fire points within the California shape
fire_data_ca = fire_data[fire_data['geometry'].apply(lambda point: california_shape.contains(point))]

# Drop geometry if needed
fire_data_ca = fire_data_ca.drop(columns='geometry')

print("Shape of filtered fire in CA:", fire_data_ca.shape)
# Out:
# Shape of unfiltered fire data: (354319, 15)
# Shape of filtered fire in CA: (301159, 15)

# %%
print("Number of fires with high confidence level:", (fire_data_ca['confidence'] == 'h').sum())
# Out:
# Number of fires with high confidence level: 21209

# %%
fire_data_ca = fire_data_ca[
    (fire_data_ca['confidence'] == 'h') & 
    (fire_data_ca['type'] == 0)
]

fire_data_ca.shape
# Out:
# (21164, 15)

# %%
from datetime import datetime
from shapely.geometry import Point
from geopy.distance import geodesic

# Convert dates to datetime
climate_data['Date'] = pd.to_datetime(climate_data['Date'])
fire_data_ca['acq_date'] = pd.to_datetime(fire_data_ca['acq_date'])

# Add label column
climate_data['fire_occurred'] = 0

# Set threshold distance in km
threshold_km = 80

# Create list of fires grouped by date
fires_by_date = fire_data_ca.groupby('acq_date')[['latitude', 'longitude']].apply(lambda x: x.values.tolist()).to_dict()

def match_fire(row):
    fires = fires_by_date.get(row['Date'], [])
    station_point = (row['Latitude'], row['Longitude'])
    for fire_point in fires:
        fire_loc = (fire_point[0], fire_point[1])
        if geodesic(station_point, fire_loc).km <= threshold_km:
            return 1
    return 0

climate_data['fire_occurred'] = climate_data.apply(match_fire, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 27
#      24             return 1
#      25     return 0
# ---> 27 climate_data['fire_occurred'] = climate_data.apply(match_fire, axis=1)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[41], line 23, in match_fire(row)
#      21 for fire_point in fires:
#      22     fire_loc = (fire_point[0], fire_point[1])
# ---> 23     if geodesic(station_point, fire_loc).km <= threshold_km:
#      24         return 1
#      25 return 0
#
# File /opt/anaconda3/lib/python3.12/site-packages/geopy/distance.py:540, in geodesic.__init__(self, *args, **kwargs)
#     538 self.set_ellipsoid(kwargs.pop('ellipsoid', 'WGS-84'))
#     539 major, minor, f = self.ELLIPSOID
# --> 540 super().__init__(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/geopy/distance.py:276, in Distance.__init__(self, *args, **kwargs)
#     274 elif len(args) > 1:
#     275     for a, b in util.pairwise(args):
# --> 276         kilometers += self.measure(a, b)
#     278 kilometers += units.kilometers(**kwargs)
#     279 self.__kilometers = kilometers
#
# File /opt/anaconda3/lib/python3.12/site-packages/geopy/distance.py:566, in geodesic.measure(self, a, b)
#     561 if not (isinstance(self.geod, Geodesic) and
#     562         self.geod.a == self.ELLIPSOID[0] and
#     563         self.geod.f == self.ELLIPSOID[2]):
#     564     self.geod = Geodesic(self.ELLIPSOID[0], self.ELLIPSOID[2])
# --> 566 s12 = self.geod.Inverse(lat1, lon1, lat2, lon2,
#     567                         Geodesic.DISTANCE)['s12']
#     569 return s12
#
# File /opt/anaconda3/lib/python3.12/site-packages/geographiclib/geodesic.py:1030, in Geodesic.Inverse(self, lat1, lon1, lat2, lon2, outmask)
#    1012 def Inverse(self, lat1, lon1, lat2, lon2,
#    1013             outmask = GeodesicCapability.STANDARD):
#    1014   """Solve the inverse geodesic problem
#    1015
#    1016   :param lat1: latitude of the first point in degrees
#    (...)
#    1027
#    1028   """
# -> 1030   a12, s12, salp1,calp1, salp2,calp2, m12, M12, M21, S12 = self._GenInverse(
#    1031     lat1, lon1, lat2, lon2, outmask)
#    1032   outmask &= Geodesic.OUT_MASK
#    1033   if outmask & Geodesic.LONG_UNROLL:
#
# File /opt/anaconda3/lib/python3.12/site-packages/geographiclib/geodesic.py:876, in Geodesic._GenInverse(self, lat1, lon1, lat2, lon2, outmask)
#     870 salp1b = Geodesic.tiny_; calp1b = -1.0
#     872 while numit < Geodesic.maxit2_:
#     873   # the WGS84 test set: mean = 1.47, sd = 1.25, max = 16
#     874   # WGS84 and random input: mean = 2.85, sd = 0.60
#     875   (v, salp2, calp2, sig12, ssig1, csig1, ssig2, csig2,
# --> 876    eps, domg12, dv) = self._Lambda12(
#     877      sbet1, cbet1, dn1, sbet2, cbet2, dn2,
#     878      salp1, calp1, slam12, clam12, numit < Geodesic.maxit1_,
#     879      C1a, C2a, C3a)
#     880   # Reversed test to allow escape with NaNs
#     881   if tripb or not (abs(v) >= (8 if tripn else 1) * Geodesic.tol0_):
#
# File /opt/anaconda3/lib/python3.12/site-packages/geographiclib/geodesic.py:680, in Geodesic._Lambda12(self, sbet1, cbet1, dn1, sbet2, cbet2, dn2, salp1, calp1, slam120, clam120, diffp, C1a, C2a, C3a)
#     678 k2 = Math.sq(calp0) * self._ep2
#     679 eps = k2 / (2 * (1 + math.sqrt(1 + k2)) + k2)
# --> 680 self._C3f(eps, C3a)
#     681 B312 = (Geodesic._SinCosSeries(True, ssig2, csig2, C3a) -
#     682         Geodesic._SinCosSeries(True, ssig1, csig1, C3a))
#     683 domg12 =  -self.f * self._A3f(eps) * salp0 * (sig12 + B312)
#
# File /opt/anaconda3/lib/python3.12/site-packages/geographiclib/geodesic.py:414, in Geodesic._C3f(self, eps, c)
#     412 m = Geodesic.nC3_ - l - 1       # order of polynomial in eps
#     413 mult *= eps
# --> 414 c[l] = mult * Math.polyval(m, self._C3x, o, eps)
#     415 o += m + 1
#
# File /opt/anaconda3/lib/python3.12/site-packages/geographiclib/geomath.py:67, in Math.polyval(N, p, s, x)
#      63 @staticmethod
#      64 def polyval(N, p, s, x):
#      65   """Evaluate a polynomial."""
# ---> 67   y = float(0 if N < 0 else p[s]) # make sure the returned value is a float
#      68   while N > 0:
#      69     N -= 1; s += 1
#
# KeyboardInterrupt:

# %%
print(climate_data['Stn Id'].nunique())
# Out:
# 142

# %%
climate_data[climate_data.fire_occurred == 1]
# Out:
#         Stn Id             Stn Name         CIMIS Region       Date  Jul  \
# 1587       182               Delano   San Joaquin Valley 2021-05-07  127
# 1736       182               Delano   San Joaquin Valley 2021-10-03  276
# 6087       187          Black Point  North Coast Valleys 2021-09-01  244
# 11576      192       Lake Arrowhead       San Bernardino 2024-09-11  255
# 13189      113  King City-Oasis Rd.         Monterey Bay 2021-02-10   41
# ...        ...                  ...                  ...        ...  ...
# 207717     114          Arroyo Seco         Monterey Bay 2024-07-23  205
# 207858     114          Arroyo Seco         Monterey Bay 2024-12-11  346
# 209898     117          Victorville       San Bernardino 2022-07-13  194
# 213162     125         Arvin-Edison   San Joaquin Valley 2023-06-20  171
# 213491     125         Arvin-Edison   San Joaquin Valley 2024-05-14  135
#
#         ETo (mm) qc  Precip (mm) qc.1  Sol Rad (W/sq.m)  ... qc.10  \
# 1587        6.18             0.0                  340.0  ...
# 1736        3.88             0.0                  208.0  ...
# 6087        4.38             0.1                  262.0  ...
# 11576       5.06             0.8                  241.0  ...
# 13189       2.20             0.0                  150.0  ...
# ...          ... ..          ...  ...               ...  ...   ...
# 207717      6.80             0.0                  317.0  ...
# 207858      1.88             0.0                  122.0  ...
# 209898      8.91             0.0                  357.0  ...
# 213162      7.16             0.0                  361.0  ...
# 213491      7.12             0.0                  337.0  ...
#
#         Avg Wind Speed (m/s) qc.11  Wind Run (km) qc.12  Avg Soil Temp (C)  \
# 1587                     1.7                144.9                     21.7
# 1736                     1.1                 95.8                     17.6
# 6087                     1.8                157.5                     20.8
# 11576                    2.5                215.7                     16.5
# 13189                    2.2                186.0                     10.6
# ...                      ...   ...            ...   ...                ...
# 207717                   2.7                232.2                     21.3
# 207858                   1.5                127.4                     10.1
# 209898                   2.8                241.6                     19.9
# 213162                   2.4                205.1                     27.3
# 213491                   1.5                130.4                     31.1
#
#        qc.13   Latitude  Longitude  fire_occurred
# 1587          35.833000 -119.25596              1
# 1736          35.833000 -119.25596              1
# 6087          38.090933 -122.52670              1
# 11576         34.255942 -117.21814              1
# 13189         36.121083 -121.08457              1
# ...      ...        ...        ...            ...
# 207717        36.347306 -121.29135              1
# 207858        36.347306 -121.29135              1
# 209898        34.475914 -117.26351              1
# 213162        35.205583 -118.77841              1
# 213491     R  35.205583 -118.77841              1
#
# [288 rows x 36 columns]
